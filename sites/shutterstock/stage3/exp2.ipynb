# %%
import torch
import numpy as np
from PIL import Image

# %%
tensor_in = np.load("/home/windowsuser/crawlers/sites/shutterstock/stage3/tmp/4854749_0_pipe_in.npy")
tensor_out = np.load("/home/windowsuser/crawlers/sites/shutterstock/stage3/tmp/4854749_0_pipe_out.npy")
print(tensor_in.shape, tensor_out.shape)
print(tensor_in.dtype, tensor_out.dtype)
# Out:
# (16, 384, 640, 3) (16, 384, 640, 3)
# uint8 uint8

# %%
frame_in = tensor_in[0]
frame_out = tensor_out[0]
print(frame_in.shape, frame_out.shape)
print(frame_in.dtype, frame_out.dtype)
# Out:
# (384, 640, 3) (384, 640, 3)
# uint8 uint8

# %%
img_in = Image.fromarray(frame_in)
img_out = Image.fromarray(frame_out)

# %%
img_in
# Out:
# <PIL.Image.Image image mode=RGB size=640x384>

# %%
img_out
# Out:
# <PIL.Image.Image image mode=RGB size=640x384>
